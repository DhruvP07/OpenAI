# %%
#pip install --upgrade openai
# Out:
# Requirement already satisfied: openai in c:\users\dhruv\anaconda3\envs\testingopenai\lib\site-packages (0.28.0)Note: you may need to restart the kernel to use updated packages.
#
# Collecting openai
#   Using cached openai-1.70.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\dhruv\anaconda3\envs\testingopenai\lib\site-packages (from openai) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\dhruv\anaconda3\envs\testingopenai\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\dhruv\anaconda3\envs\testingopenai\lib\site-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\dhruv\anaconda3\envs\testingopenai\lib\site-packages (from openai) (0.7.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\dhruv\anaconda3\envs\testingopenai\lib\site-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in c:\users\dhruv\anaconda3\envs\testingopenai\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\dhruv\anaconda3\envs\testingopenai\lib\site-packages (from openai) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\dhruv\anaconda3\envs\testingopenai\lib\site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in c:\users\dhruv\anaconda3\envs\testingopenai\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\dhruv\anaconda3\envs\testingopenai\lib\site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in c:\users\dhruv\anaconda3\envs\testingopenai\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\dhruv\anaconda3\envs\testingopenai\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\dhruv\anaconda3\envs\testingopenai\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dhruv\anaconda3\envs\testingopenai\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\dhruv\anaconda3\envs\testingopenai\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Requirement already satisfied: colorama in c:\users\dhruv\anaconda3\envs\testingopenai\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Using cached openai-1.70.0-py3-none-any.whl (599 kB)
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 0.28.0
#     Uninstalling openai-0.28.0:
#       Successfully uninstalled openai-0.28.0
# Successfully installed openai-1.70.0

# %%
import requests
import os
import openai
import json
from openai import AzureOpenAI

# %%
#openapi settings and kets
AZURE_OPENAI_ENDPOINT = "https://dev-m8z8ixgl-swedencentral.cognitiveservices.azure.com/"
AZURE_OPENAI_KEY = "5N6F67cqcwVKqlxpZB6a5BrXTVDTvDpGOiEtbl6GbrzcoZ8X3gQzJQQJ99BDACfhMk5XJ3w3AAAAACOGKm4w"


DEPLOYMENT_NAME_TEXT = "gpt-4o"    
DEPLOYMENT_NAME_IMAGE = "dall-e-3" 


openai.api_type = "azure"
#openai.api_base = AZURE_OPENAI_ENDPOINT
#openai.api_key = AZURE_OPENAI_KEY
openai.api_version = "2025-01-01-preview"  #api version for gpt 4o

# %%
client = AzureOpenAI(
    api_version = "2025-01-01-preview",
    azure_endpoint = AZURE_OPENAI_ENDPOINT,
    api_key = AZURE_OPENAI_KEY,
)

# %%
# Define the directory name
directory_name = "Metro_cities_Images"

# Create the directory
if not os.path.exists(directory_name):
    os.makedirs(directory_name)
    print(f"Directory '{directory_name}' created.")
else:
    print(f"Directory '{directory_name}' already exists.")
# Out:
# Directory 'Metro_cities_Images' created.

# %%
def generate_text(prompt):
    response = client.chat.completions.create(
        model = DEPLOYMENT_NAME_TEXT, 
        messages=[{"role": "user", "content": prompt}]
    )
    return response.choices[0].message.content

# %%
def generate_text_prompt(city, state):
    prompt = f"""Provide a structured overview of the {city}, {state} metro area. 
        Detail instructions:
         a) send result in paragraph form, with one paragraph per topic and 3 to 5 sentences per paragraph. 
         b) Cover the following topics 1 thru 5. 
         c) Include meaningful metrics in each topic paragraph that will be actually useful for investors and buyers. Don't give minute metrics that are not very meaningful. 
         d) Put a brief topic heading before each paragraph 
         e) If relevant graphs or images are available, include those 
        
        Topics to cover are below: 
        1. General: General description including history, location, climate, landscape, recreation activities.
        2. Towns: Key towns in metro, Page/race demographics. 
        3. Economy: Strength of economy, unemployment rates, job growth trends, types of industries and employers like govt, medical, military, etc and any significant concentration of employer types. Include notable employer names if any. 
        4. Transportation: airports, public transportation, highways (very short paragraph).
        5. Market: Housing market and comparison with national averages in prices, rents and growth.
        
        Give me output in json format(with delimiters, and double inverted commas enclosing keys and values), with General, Towns, Economy, Transportation, and Market as keys and their paragraphs as values.
        output format: 
        {{
            "General": "<Paragraph 1>",
            "Towns": "<Paragraph 2>",
            "Economy": "<Paragraph 3>",
            "Transportation": "<Paragraph 4>",
            "Market": "<Paragraph 5>"
        }}

        Instructions about the format of the output:
            1. Please avoid writing anything outside of the json.
            2. Always include Delimiters (commas between key-value pairs)
        """
    return prompt

# %%
def generate_image(prompt):
    response = client.images.generate(
        model = DEPLOYMENT_NAME_IMAGE, 
        prompt= prompt,
        size = "1024x1024",
    )
    return response.data[0].url

# %%
def generate_image_prompt(city, state):
    image_prompt = f"""Generate me an Image of {city}, {state} that represents its Skyline, Downtown, and its essence."""
    return image_prompt

# %%
with open('cities_cluster2.json', 'r') as file:
    cities_state_data = json.load(file)

# %%
# Iteratively find the Json with Metro report for each city.

metro_report = {}
count = 0
for key, value in cities_state_data.items():
    try:
        city, state = key.split("_")
        text = generate_text(generate_text_prompt(city, state))
        text = text.strip()
        text = json.loads(text)
            
        image_url = generate_image(generate_image_prompt(city, state))     
        response = requests.get(image_url)
        
        with open(f"Metro_cities_Images/{key}.png", "wb") as f:
            f.write(response.content)

        text["Image_path"] =  f"Metro_cities_Images/{key}.png"
        metro_report[f"{city}_{state}"]= text
        
        print(city+"_"+state+":", text)
    
    except Exception as e:
        metro_report[f"{city}_{state}"]= {}
        print(f"Error processing {key}: {e}")
        count= count + 1
# Out:
# Brooklyn_NY: {'General': 'Brooklyn, NY, is one of the five boroughs of New York City and is situated on the western end of Long Island. Known for its rich history dating back to its founding in the 1600s, Brooklyn has grown into a cultural and economic hub with world-renowned landmarks such as the Brooklyn Bridge and Prospect Park. The region experiences a humid subtropical climate, with average annual temperatures ranging from 27°F in January to 84°F in July. Recreational opportunities are abundant, including scenic walks along the Brooklyn Heights Promenade, cultural experiences at the Brooklyn Museum, and events at the Barclays Center. Investors often value the area’s vibrant mix of arts, parks, and historic venues as drivers of tourism and community engagement.', 'Towns': 'Brooklyn metro consists of notable neighborhoods and towns such as Williamsburg, Dumbo, Park Slope, and Downtown Brooklyn, each offering its unique character and amenities. The borough’s racial demographics are diverse, with approximately 35% White, 29% Black or African American, 19% Hispanic or Latino, and 12% Asian populations according to recent census data. A comparatively younger population, with a median age of around 35 years, is complemented by a growing mix of families, young professionals, and immigrant communities. Investors frequently focus on neighborhoods like Dumbo for luxury and tech-driven development, while Park Slope offers charm with historic brownstones and family-centric amenities.', 'Economy': 'Brooklyn exhibits a robust and diverse economy with prominent industries including healthcare, technology, manufacturing, and retail. The area boasts major employers such as NewYork-Presbyterian Hospital, Brooklyn Navy Yard, and Etsy, supporting both long-term economic stability and innovation. As of late 2023, Brooklyn’s unemployment rate stands at approximately 4%, aligning closely with national averages, while job growth has been steady at around 2.5% annually. An increasing presence of startups, co-working spaces, and shared innovation hubs has attracted young professionals and businesses seeking to leverage the borough’s proximity to Manhattan and its cultural appeal.', 'Transportation': 'Brooklyn offers exceptional transportation connectivity with major highways such as the Brooklyn-Queens Expressway (BQE) and Belt Parkway. Public transit is highly developed, with 18 subway lines and several bus routes linking Brooklyn to other parts of New York City. Additionally, the borough is accessible via John F. Kennedy International Airport (approximately 25 minutes away) and LaGuardia Airport (about 30 minutes away), making it a prime location for both domestic and international travel. Investors and businesses highly value the ease of access to transportation hubs.', 'Market': "Brooklyn's housing market is dynamic, with median home prices at approximately $900,000, significantly above the national average of $375,000. Rental costs average $3,200 per month, reflecting strong demand driven by proximity to Manhattan and cultural vibrancy. Home values have grown by more than 5% annually over the past five years, showcasing resilience and increasing investor confidence. Despite higher-than-average costs, strong rental yields and a tight inventory of properties contribute to Brooklyn's appeal as a prime real estate investment location.", 'Image_path': 'Metro_cities_Images/Brooklyn_NY.png'}
high median household incomes and upscale amenities.', 'Economy': "The Chicago metro area's economy is robust, with a GDP exceeding $850 billion, placing it among the top global urban economies. Unemployment rates hover around 4.2%, aligning closely with national averages, and the region has seen positive job growth trends in technology, healthcare, finance, and logistics. Major industries include manufacturing, finance (home to CME Group and major banking institutions), healthcare (with Northwestern Memorial and Advocate Health prominent), and transportation (a sector buoyed by Chicago’s status as a railroad and air hub). Employers such as Boeing, McDonald’s, and Walgreens maintain headquarters here, along with federal government offices and state agencies.", 'Transportation': "Chicago is a major transportation hub, with O’Hare International and Midway Airports offering expansive domestic and international connectivity. Public transportation is provided by the Chicago Transit Authority (CTA) via buses and the iconic 'L' train system, complemented by Metra's commuter rail lines serving suburban areas. Interstate highways such as I-90, I-55, and I-94 provide efficient regional access, making both commuting and logistics seamless for residents and businesses alike.", 'Market': 'The housing market in the Chicago metro area remains reasonably priced compared to other major U.S. metros, with a median home price of approximately $329,000—lower than the national average of around $416,000. Rent averages $1,950/month, slightly above the national average of $1,750/month, but growth in rents has tapered to a modest 2-4% year-over-year. While some suburban markets like Naperville show higher appreciation rates due to strong demand, value-focused investors are finding opportunities in transitioning neighborhoods within Chicago proper. Overall, affordability and steady market growth make the area attractive to buyers.', 'Image_path': 'Metro_cities_Images/Chicago_IL.png'}
# San-Antonio_TX: {'General': 'San Antonio, Texas, is a dynamic metro area rich in history and culture, situated in south-central Texas. Known for landmarks like the Alamo, its historical significance dates back to pivotal events in the Texas Revolution. The city enjoys a warm, semi-arid climate with hot summers and mild winters, making it a favorable environment for outdoor activities year-round. The area offers diverse recreational options, including hiking in the Texas Hill Country, exploring the River Walk, and visiting cultural institutions like the San Antonio Museum of Art. Its relatively flat landscape transitions to rolling hills as you move north of the city.', 'Towns': 'The San Antonio metro area includes key towns such as New Braunfels, Converse, and Seguin, each with unique characteristics. San Antonio itself is ethnically diverse, with a population that is approximately 64% Hispanic or Latino, 25% White, and 7% Black or African American, according to recent census data. New Braunfels stands out for its German heritage and high household income, while Seguin is known for its smaller-town charm and growing industrial presence. The area’s population has been growing rapidly, with San Antonio ranking as the 7th largest city in the U.S., boasting a metro population of over 2.6 million.', 'Economy': 'San Antonio has a robust economy anchored by industries such as healthcare, aerospace, military defense, and tourism. Notable employers include USAA, H-E-B, Boeing, and military installations like Joint Base San Antonio, the largest joint base in the Department of Defense. The unemployment rate in the area is approximately 3.9%, slightly below the national average. Job growth trends are positive, with an expected annual growth rate of nearly 2.5%, making it appealing for investors and buyers seeking long-term economic stability and expansion.', 'Transportation': 'San Antonio is served by the San Antonio International Airport, which provides connections to major national and international destinations. The city’s transportation infrastructure includes major highways such as I-10, I-35, and I-410, facilitating easy travel within Texas and beyond. Public transportation is managed by VIA Metropolitan Transit, offering bus and rideshare services, though its reach is limited compared to major metros like Houston or Dallas.', 'Market': 'The housing market in San Antonio is relatively affordable, with median home prices around $295,000, compared to the national median of $416,100 as of 2023. Renters can expect an average monthly rent of approximately $1,250, below the national median of $1,900. Despite the affordability, home values have experienced steady annual growth of approximately 6%, reflecting strong buyer interest and expanding demand. This combination of affordability and growth makes San Antonio attractive for both first-time homebuyers and real estate investors.', 'Image_path': 'Metro_cities_Images/San-Antonio_TX.png'}
# Minneapolis_MN: {'General': "The Minneapolis-St. Paul metropolitan area, often called the Twin Cities, is located in southeastern Minnesota along the Mississippi River. Minneapolis itself is one of the most populous cities in the Midwest, while St. Paul serves as the state capital. The region experiences a continental climate with warm summers and cold, snowy winters, which are ideal for seasonal recreational activities like skiing, ice fishing, and boating on its numerous lakes—Minnesota is nicknamed the 'Land of 10,000 Lakes.' Beyond its natural appeal, Minneapolis has a rich history linked to milling and commerce due to its proximity to the Mississippi River and Saint Anthony Falls.", 'Towns': 'The metro area includes key towns such as Minneapolis, St. Paul, Bloomington, and Eden Prairie. According to Census data, Minneapolis-St. Paul metro has a population of over 3.7 million, and its demographics reflect increasing diversity, with approximately 68% identifying as White, 13% as African American, 8% as Asian, and 8% as Hispanic or Latino. St. Paul has a notably strong Hmong and Somali community, while suburbs such as Edina and Minnetonka are considered affluent and heavily residential, attracting buyers with their high-quality schools and amenities.', 'Economy': 'The Twin Cities metro boasts a strong and diverse economy, with a low unemployment rate of 2.8% as of 2023, below the national average. The area is home to major Fortune 500 companies such as Target, Best Buy, General Mills, and UnitedHealth Group. Other leading industries include healthcare, education, technology, and manufacturing, with significant employers like Mayo Clinic, University of Minnesota, and Medtronic. Additionally, there’s growing tech industry activity centered in the urban core, highlighting steady job growth trends in IT and biosciences.', 'Transportation': 'Minneapolis-St. Paul offers robust transportation options including Minneapolis-Saint Paul International Airport (MSP), one of the busiest airports in the U.S., serving over 25 million passengers annually. The area features an expanding public transit network with Metro Transit buses and light rail lines, including the Blue and Green Lines connecting key parts of the metro. Major highways such as I-94, I-35, and I-494 offer efficient road access within the region and beyond.', 'Market': 'The Twin Cities housing market has seen steady appreciation, with the median home price at roughly $350,000 in 2023—below the national median of $379,000, making it an attractive market for buyers. Rental rates average around $1,500 per month for a two-bedroom apartment, which closely aligns with national averages. While growth rates in housing prices have slowed compared to the pandemic era, the local market remains relatively competitive, driven by high demand and limited inventory in suburban areas. For investors, the strong rental demand and positive appreciation trajectory make it a solid market consideration.', 'Image_path': 'Metro_cities_Images/Minneapolis_MN.png'}
# Miami_FL: {'General': 'The Miami metropolitan area, located in southeastern Florida, is a major urban hub with a rich history dating back to its founding in the late 19th century. Known for its tropical climate, Miami offers warm weather year-round, averaging highs of 75°F in winter and over 90°F in summer. The region features notable landscapes such as pristine beaches, the nearby Everglades National Park, and Biscayne Bay, which attracts millions of visitors annually for recreation activities like boating, fishing, and kayaking. Miami’s vibrant cultural scene includes world-class museums, a thriving nightlife, and notable events such as Art Basel Miami Beach.', 'Towns': "The Miami metro area encompasses key cities including Miami, Fort Lauderdale, and Hialeah, among others. Miami is the largest city and hub for international tourism and commerce, while Fort Lauderdale is renowned for its boating culture and beaches. The area has a diverse population with Hispanic or Latino residents comprising over 70%, African Americans making up around 18%, and Whites accounting for approximately 10%. This melting pot of cultures contributes to the region's dynamic food, music, and arts scenes, making it high
Augustine along with Jacksonville itself. Jacksonville is racially and ethnically diverse, with approximately 58% of residents identifying as White, 31% as Black or African American, 9% as Hispanic or Latino, and 4% as Asian as per the latest U.S. Census data. Orange Park offers family-friendly suburban living, while Ponte Vedra Beach is known for its affluent communities and golf resorts, including the Players Championship. St. Augustine, the nation’s oldest city, draws residents and visitors alike with its rich historical significance and arts scene.', 'Economy': 'Jacksonville has a robust economy supported by its port, logistics industry, healthcare sector, and military presence. It boasts an unemployment rate of approximately 3.1%, outperforming the national average. Major industries include banking, with companies like Florida Blue and Deutsche Bank headquartered here, as well as logistics and shipping led by the Jacksonville Port Authority. The healthcare sector is anchored by organizations like Baptist Health and Mayo Clinic, while military installations such as Naval Station Mayport contribute significantly to employment. Job growth trends are strong, with annual growth exceeding 3% in high-demand fields such as technology and real estate.', 'Transportation': 'Jacksonville is served by Jacksonville International Airport (JAX), which connects the city to major destinations across the country. Public transportation is provided through the Jacksonville Transportation Authority (JTA) with buses, a monorail system called the Skyway, and regional support services. Interstate 95 and Interstate 10 cross Jacksonville, making it a key highway hub for travel and freight movement in the southeastern United States.', 'Market': 'The housing market in Jacksonville is marked by affordability compared to most other metropolitan areas in the United States. As of 2023, the median home price is around $320,000, significantly below the national average of $428,000, while rents average $1,515 per month. Property values in the metro have appreciated by 8% annually over the last five years, reflecting healthy demand and growth potential. The combination of affordability and steady price appreciation makes Jacksonville a highly attractive market for investors and buyers in both residential and rental sectors.', 'Image_path': 'Metro_cities_Images/Jacksonville_FL.png'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 8
#       6 try:
#       7     city, state = key.split("_")
# ----> 8     text = generate_text(generate_text_prompt(city, state))
#       9     text = text.strip()
#      10     text = json.loads(text)
#
# Cell In[5], line 2, in generate_text(prompt)
#       1 def generate_text(prompt):
# ----> 2     response = client.chat.completions.create(
#       3         model = DEPLOYMENT_NAME_TEXT,
#       4         messages=[{"role": "user", "content": prompt}]
#       5     )
#       6     return response.choices[0].message.content
#
# File ~\anaconda3\envs\testingopenai\lib\site-packages\openai\_utils\_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\testingopenai\lib\site-packages\openai\resources\chat\completions\completions.py:914, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     871 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     872 def create(
#     873     self,
#    (...)
#     911     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     912 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     913     validate_response_format(response_format)
# --> 914     return self._post(
#     915         "/chat/completions",
#     916         body=maybe_transform(
#     917             {
#     918                 "messages": messages,
#     919                 "model": model,
#     920                 "audio": audio,
#     921                 "frequency_penalty": frequency_penalty,
#     922                 "function_call": function_call,
#     923                 "functions": functions,
#     924                 "logit_bias": logit_bias,
#     925                 "logprobs": logprobs,
#     926                 "max_completion_tokens": max_completion_tokens,
#     927                 "max_tokens": max_tokens,
#     928                 "metadata": metadata,
#     929                 "modalities": modalities,
#     930                 "n": n,
#     931                 "parallel_tool_calls": parallel_tool_calls,
#     932                 "prediction": prediction,
#     933                 "presence_penalty": presence_penalty,
#     934                 "reasoning_effort": reasoning_effort,
#     935                 "response_format": response_format,
#     936                 "seed": seed,
#     937                 "service_tier": service_tier,
#     938                 "stop": stop,
#     939                 "store": store,
#     940                 "stream": stream,
#     941                 "stream_options": stream_options,
#     942                 "temperature": temperature,
#     943                 "tool_choice": tool_choice,
#     944                 "tools": tools,
#     945                 "top_logprobs": top_logprobs,
#     946                 "top_p": top_p,
#     947                 "user": user,
#     948                 "web_search_options": web_search_options,
#     949             },
#     950             completion_create_params.CompletionCreateParams,
#     951         ),
#     952         options=make_request_options(
#     953             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     954         ),
#     955         cast_to=ChatCompletion,
#     956         stream=stream or False,
#     957         stream_cls=Stream[ChatCompletionChunk],
#     958     )
#
# File ~\anaconda3\envs\testingopenai\lib\site-packages\openai\_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1228 def post(
#    1229     self,
#    1230     path: str,
#    (...)
#    1237     stream_cls: type[_StreamT] | None = None,
#    1238 ) -> ResponseT | _StreamT:
#    1239     opts = FinalRequestOptions.construct(
#    1240         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241     )
# -> 1242     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\anaconda3\envs\testingopenai\lib\site-packages\openai\_base_client.py:919, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     916 else:
#     917     retries_taken = 0
# --> 919 return self._request(
#     920     cast_to=cast_to,
#     921     options=options,
#     922     stream=stream,
#     923     stream_cls=stream_cls,
#     924     retries_taken=retries_taken,
#     925 )
#
# File ~\anaconda3\envs\testingopenai\lib\site-packages\openai\_base_client.py:964, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     961 log.debug("Encountered httpx.TimeoutException", exc_info=True)
#     963 if remaining_retries > 0:
# --> 964     return self._retry_request(
#     965         input_options,
#     966         cast_to,
#     967         retries_taken=retries_taken,
#     968         stream=stream,
#     969         stream_cls=stream_cls,
#     970         response_headers=None,
#     971     )
#     973 log.debug("Raising timeout error")
#     974 raise APITimeoutError(request=request) from err
#
# File ~\anaconda3\envs\testingopenai\lib\site-packages\openai\_base_client.py:1057, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1053 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1054 # different thread if necessary.
#    1055 time.sleep(timeout)
# -> 1057 return self._request(
#    1058     options=options,
#    1059     cast_to=cast_to,
#    1060     retries_taken=retries_taken + 1,
#    1061     stream=stream,
#    1062     stream_cls=stream_cls,
#    1063 )
#
# File ~\anaconda3\envs\testingopenai\lib\site-packages\openai\_base_client.py:955, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     952 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     954 try:
# --> 955     response = self._client.send(
#     956         request,
#     957         stream=stream or self._should_stream_response_body(request=request),
#     958         **kwargs,
#     959     )
#     960 except httpx.TimeoutException as err:
#     961     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~\anaconda3\envs\testingopenai\lib\site-packages\httpx\_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File ~\anaconda3\envs\testingopenai\lib\site-packages\httpx\_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File ~\anaconda3\envs\testingopenai\lib\site-packages\httpx\_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File ~\anaconda3\envs\testingopenai\lib\site-packages\httpx\_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File ~\anaconda3\envs\testingopenai\lib\site-packages\httpx\_transports\default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File ~\anaconda3\envs\testingopenai\lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~\anaconda3\envs\testingopenai\lib\site-packages\httpcore\_sync\connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~\anaconda3\envs\testingopenai\lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File ~\anaconda3\envs\testingopenai\lib\site-packages\httpcore\_sync\http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File ~\anaconda3\envs\testingopenai\lib\site-packages\httpcore\_sync\http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File ~\anaconda3\envs\testingopenai\lib\site-packages\httpcore\_sync\http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File ~\anaconda3\envs\testingopenai\lib\site-packages\httpcore\_sync\http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\anaconda3\envs\testingopenai\lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File ~\anaconda3\envs\testingopenai\lib\ssl.py:1260, in SSLSocket.recv(self, buflen, flags)
#    1256     if flags != 0:
#    1257         raise ValueError(
#    1258             "non-zero flags not allowed in calls to recv() on %s" %
#    1259             self.__class__)
# -> 1260     return self.read(buflen)
#    1261 else:
#    1262     return super().recv(buflen, flags)
#
# File ~\anaconda3\envs\testingopenai\lib\ssl.py:1135, in SSLSocket.read(self, len, buffer)
#    1133         return self._sslobj.read(len, buffer)
#    1134     else:
# -> 1135         return self._sslobj.read(len)
#    1136 except SSLError as x:
#    1137     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
with open('metro_report.json', 'w') as file:
    json.dump(metro_report, file, indent=4)

# %%
# Open the file

with open('metro_report.json', 'r') as file:
    new_metro_report = json.load(file)

# Edit
while(count!=0):
    for key, value in new_metro_report.items():
        if not new_metro_report[key]:
            print(key)
            try:
                city, state = key.split("_")
                text = generate_text(generate_text_prompt(city, state))
                text = text.strip()
                text = json.loads(text)
                
                image_url = generate_image(generate_image_prompt(city, state))     
                response = requests.get(image_url)
                
                with open(f"Metro_cities_Images/{key}.png", "wb") as f:
                    f.write(response.content)
        
                text["Image_path"] =  f"Metro_cities_Images/{key}.png"
                new_metro_report[f"{city}_{state}"]= text
                
                print(city+"_"+state+":", text)
                count = count - 1
        
            except Exception as e:
                new_metro_report[f"{city}_{state}"]= {}
                print(f"Error processing {key}: {e}")

#print(metro_report)
# Out:
# Philadelphia_PA
# Philadelphia_PA: {'General': 'The Philadelphia metro area, also known as the Delaware Valley, is located in southeastern Pennsylvania, extending into parts of Delaware, New Jersey, and Maryland. Known for its rich history as the birthplace of the United States, Philadelphia is home to iconic landmarks such as Independence Hall and the Liberty Bell. This region experiences a humid subtropical climate, with hot summers and cold winters, making it ideal for year-round activities such as hiking in the Appalachian foothills or exploring waterfronts along the Delaware River. The metro area also offers ample recreational opportunities, including museums, cultural festivals, and professional sports teams like the Eagles, Phillies, and 76ers, offering residents and visitors entertainment throughout the year.', 'Towns': 'The Philadelphia metro area consists of key towns and cities, including Philadelphia itself, Bala Cynwyd, King of Prussia, Cherry Hill, Camden, and Wilmington. Philadelphia is a diverse city with a population of over 1.58 million, while the larger metro area is home to approximately 6.2 million residents. The region is characterized by a mix of racial and ethnic demographics, including 39% White, 32% Black or African-American, 14% Hispanic or Latino, and 7% Asian populations, creating a multicultural environment attractive to families and businesses alike. Suburban towns like King of Prussia and Malvern are known for their affluent communities and family-oriented amenities, while areas like Camden have been undergoing efforts to revitalize urban development.', 'Economy': "The Philadelphia metro area boasts a strong and diversified economy, with an unemployment rate of approximately 4%, which generally aligns with national averages. Major industries driving growth include healthcare, education, financial services, biotechnology, and government. Key employers in the region include Comcast Corporation, Jefferson Health, University of Pennsylvania, and the Philadelphia Naval Shipyard. The metro area also benefits from a significant concentration of medical and educational institutions, anchored by 'eds and meds' sectors, making it a stable and attractive environment for investment in both residential and commercial markets.", 'Transportation': "The Philadelphia metro area's transportation infrastructure is robust, featuring Philadelphia International Airport (PHL), a major hub for domestic and international travel. Public transportation is serviced by SEPTA, which operates buses, trains, and trolleys, making daily commutes convenient for residents. Additionally, highways such as I-95, I-76, and the Pennsylvania Turnpike provide critical connectivity across the region, facilitating both passenger and freight movement across state lines.", 'Market': "Philadelphia's housing market is moderately priced compared to national averages, with median home values around $280,000, lower than the national median of about $430,000. Rental prices average $1,800 per month, making it attractive to those seeking affordability in urban living. Over the past year, home price appreciation has been steady, at roughly 4% annually, which is slightly below national trends. Investors are particularly drawn to revitalized urban neighborhoods and suburban developments, which offer opportunities in both buy-and-hold and fix-and-flip strategies.", 'Image_path': 'Metro_cities_Images/Philadelphia_PA.png'}

# %%
with open('metro_report.json', 'w') as file:
    json.dump(new_metro_report, file, indent=4)

# %%
### Testing

# %%
image_url = "https://dalleprodsec.blob.core.windows.net/private/images/f13cf10b-32c6-4af8-aa9b-09821efc4258/generated_00.png?se=2025-04-07T17%3A46%3A19Z&sig=RZDPOZRVqXEP9QBeYw1L94jylfzW87rucJQOGMXQn4w%3D&ske=2025-04-11T01%3A23%3A53Z&skoid=e52d5ed7-0657-4f62-bc12-7e5dbb260a96&sks=b&skt=2025-04-04T01%3A23%3A53Z&sktid=33e01921-4d64-4f8c-a055-5bdaffd5e33d&skv=2020-10-02&sp=r&spr=https&sr=b&sv=2020-10-02"
response = requests.get(image_url)

with open("Metro_cities_Images/dalle_image.png", "wb") as f:
    f.write(response.content)
